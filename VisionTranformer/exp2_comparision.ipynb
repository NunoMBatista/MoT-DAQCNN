# %% [markdown]
# ### In this notebook, we attempt to start the intial comparision between a classical VIT and Hybrid VIT(quantum+ classical)...

# %% [markdown]
# - Step 1: generate full dataset using the create_quantum_dataset.py
# - Step 2: define a get_subset_indices(total_size, fraction) function. By using a fixed seed, this function will return the same indices for both models.
# This is to ensure that we have the same data for training different subsets of the train data
# - Step 3: Define proper architechtures for clasical and Hybrid VIT
# - Step 4: The Classical ViT will load the raw pixels from MedMNIST using these indices.
# - Step 5: The Hybrid ViT will load the .npz features using these same indices.

# %%
# First generating the full dataset using the create quantum_dataset.py
